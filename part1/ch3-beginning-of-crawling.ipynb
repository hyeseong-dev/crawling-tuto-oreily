# %% [markdown]
# 임의의 위키백과 페이지를 가져와서 페이지에 들어 있는 링크 목록을 가져오는 파이썬 스크립트 만들기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bsObj = BeautifulSoup(html, 'html.parser')
for link in bsObj.findAll('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# tp://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-44
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-45
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-46
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-47
# #cite_ref-48
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_49-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-50
# #cite_ref-51
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-52
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-53
# http://www.drawtheline.org/sign-now/
# #cite_ref-54
# http://www.sixdegrees.org/
# #cite_ref-55
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-56
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-57
# http://baconbros.com/
# #cite_ref-58
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-59
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-60
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-61
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-62
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-63
# https://www.imdb.com/event/ev0000600/2015/1/
# #cite_ref-64
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-65
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-66
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-67
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Template:GoldenGlobeBestActorTVMiniseriesFilm
# /wiki/Template_talk:GoldenGlobeBestActorTVMiniseriesFilm
# https://en.wikipedia.org/w/index.php?title=Template:GoldenGlobeBestActorTVMiniseriesFilm&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# /wiki/Bibsys
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# /wiki/BNF_(identifier)
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# /wiki/GND_(identifier)
# https://d-nb.info/gnd/124109659
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/names/n88034930
# /wiki/National_Library_of_Latvia
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/National_Library_of_the_Czech_Republic
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# /wiki/National_Library_of_Australia
# https://nla.gov.au/anbd.aut-an36021861
# /wiki/National_Library_of_Israel
# http://uli.nli.org.il/F/?func=direct&doc_number=002168993&local_base=nlx10
# /wiki/National_Library_of_Poland
# https://tools.wmflabs.org/wikidata-externalid-url?p=1695&id=A1257000X
# /wiki/Royal_Library_of_the_Netherlands
# http://data.bibliotheken.nl/id/thes/p147880998
# /wiki/RERO_(Library_Network_of_Western_Switzerland)
# http://data.rero.ch/02-A016294166
# /wiki/SNAC
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# /wiki/Trove
# https://trove.nla.gov.au/people/1189569
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# /wiki/WorldCat_Identities_(identifier)
# https://www.worldcat.org/identities/lccn-n88034930
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=984632545
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:BLP_articles_lacking_sources_from_October_2017
# /wiki/Category:All_BLP_articles_lacking_sources
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_LNB_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA_identifiers
# /wiki/Category:Wikipedia_articles_with_NLI_identifiers
# /wiki/Category:Wikipedia_articles_with_NLP_identifiers
# /wiki/Category:Wikipedia_articles_with_NTA_identifiers
# /wiki/Category:Wikipedia_articles_with_RERO_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_Trove_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=984632545
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=984632545&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
# Out:
# str

# %%
len(bsObj.findAll('a'))
# Out:
# 909

# %% [markdown]
# 사이드바, 푸터, 헤더 링크가 있고 카테고리 페이지, 토론 페이지 등 그 외에도 우리가 관심 있어 하는 항목이 아닌 페이지를 가리키는 링크가 많이 있습니다.
#
# > - 이 링크들은 id가 bodyContent인 div 안에 있습니다.
# > - URL에는 세미콜론이 포함되어 있지 않습니다.
# > - URL은 /wiki/로 시작합니다.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bsObj = BeautifulSoup(html, 'html.parser')
# for link in bsObj.find('div',{'id':'bodyContent'}).findAll('a', href=re.compile("^(/wiki/)((?!:).)*$")):
#     if 'href' in link.attrs:
#         print(link.attrs['href'])
len(bsObj.find('div',{'id':'bodyContent'}).findAll('a', href=re.compile("^(/wiki/)((?!:).)*$")))
# Out:
# 413

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random 
import re
random.seed(datetime.datetime.now())

# %%
print(datetime.datetime.now())
# Out:
# 2020-10-23 21:56:16.431725

# %%
type(datetime.datetime.now())
# Out:
# datetime.datetime

# %%
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org'+articleUrl)
    bsObj = BeautifulSoup(html, 'html.parser')
    return bsObj.find('div', {'id': 'bodyContent'}).findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# %%
links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Kyra_Sedgwick
# /wiki/Kathy_Baker
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actress_in_a_Drama_Series
# /wiki/Robin_Wright
# /wiki/Angela_Lansbury
# /wiki/Sarah_Woodward
# /wiki/Alan_Devlin_(actor)
# /wiki/Eugene_O%27Neill
# /wiki/Desire_Under_the_Elms
# /wiki/The_Iceman_Cometh
# /wiki/Al_Hirschfeld_Theatre
# /wiki/Barnum%27s_American_Museum
# /wiki/Manhattan_Life_Insurance_Building
# /wiki/Battery_Maritime_Building
# /wiki/Maiden_Lane_(Manhattan)
# /wiki/140_Broadway
# /wiki/1166_Avenue_of_the_Americas
# /wiki/5W_Public_Relations
# /wiki/John_F._Kennedy_School_of_Government
# /wiki/Cabinet_Secretary_of_India
# /wiki/Beamter
# /wiki/Amtmann
# /wiki/Detlev_von_Liliencron
# /wiki/SNAC
# /wiki/KulturNav
# /wiki/MusicBrainz
# /wiki/MetaBrainz_Foundation
# /wiki/501(c)(3)
# /wiki/Election
# /wiki/Mandate_(politics)
# /wiki/Representative_democracy
# /wiki/Semi-presidential_system
# /wiki/European_Journal_of_Political_Research
# /wiki/Political_science
# /wiki/Dictatorship
# /wiki/Democracy_in_the_Middle_East
# /wiki/Middle_East
# /wiki/Climate_change_in_the_Middle_East_and_North_Africa
# /wiki/Climate_change_in_Morocco
# /wiki/Climate_change_in_Madagascar
# /wiki/Climate_of_Senegal
# /wiki/Mile
# /wiki/Miles_per_hour
# /wiki/Mile
# /wiki/Foot-poundal
# /wiki/British_Thermal_Unit
# /wiki/Ton_of_refrigeration
# /wiki/ASHRAE
# /wiki/Windcatcher
# /wiki/Khorasani_style
# /wiki/Jharokha
# /wiki/Medina_Haram_Piazza_Shading_Umbrellas
# /wiki/Razi_style
# /wiki/Zand_dynasty
# /wiki/Mining_in_Iran
# /wiki/Wayback_Machine
# /wiki/Federation_of_Law_Societies_of_Canada
# /wiki/Canada
# /wiki/Fran%C3%A7ois_Mitterrand
# /wiki/Supply-side_economics
# /wiki/Say%27s_Law
# /wiki/Boom_and_bust
# /wiki/Amartya_Sen
# /wiki/Simon_Kuznets
# /wiki/Net_national_income
# /wiki/Micha%C5%82_Kalecki
# /wiki/Joan_Robinson
# /wiki/Currency
# /wiki/Doi_(identifier)
# /wiki/Universal_Coded_Character_Set
# /wiki/Code_page_907
# /wiki/Mac_OS_Turkish_encoding
# /wiki/Bitstream_International_Character_Set
# /wiki/Fraction_(mathematics)
# /wiki/Egyptian_fraction
# /wiki/ISBN_(identifier)
# /wiki/Books_in_Germany
# /wiki/Book_town
# /wiki/History_of_books
# /wiki/World_Digital_Library
# /wiki/Canwest_News_Service
# /wiki/Exeter_Times-Advocate
# /wiki/The_StarPhoenix
# /wiki/The_Napanee_Guide
# /wiki/Vancouver_Sun
# /wiki/Jam!
# /wiki/Breakfast_Television
# /wiki/Breakfast_television
# /wiki/Access_31
# /wiki/WIN_HD
# /wiki/7flix
# /wiki/9Go!
# /wiki/Millionaire_Hot_Seat
# /wiki/Emergency_(2020_Australian_TV_series)
# /wiki/RBT_(TV_series)
# /wiki/High-definition_television
# /wiki/N._Ahmed
# /wiki/Node_(networking)
# /wiki/Remote_concentrator
# /wiki/Enclosure_(electrical)
# /wiki/Telcordia_Technologies
# /wiki/Information_revolution
# /wiki/Secondary_sector
# /wiki/Adhesive
# /wiki/Molecular_binding
# /wiki/Dissociation_constant
# /wiki/Equilibrium_chemistry
# /wiki/Atmospheric_chemistry
# /wiki/Stellar_chemistry
# /wiki/Nuclear_chemistry
# /wiki/National_Diet_Library
# /wiki/Terauchi_Masatake
# /wiki/Japan
# /wiki/Abdication_of_Emperor_Akihito
# /wiki/Nguy%E1%BB%85n_Xu%C3%A2n_Ph%C3%BAc
# /wiki/Communist_Party_of_Vietnam
# /wiki/List_of_national_parks_of_Vietnam
# /wiki/Standing_Committee_of_the_National_Assembly
# /wiki/Visa_policy_of_Vietnam
# /wiki/Qatar
# /wiki/Next_Qatari_general_election
# /wiki/2007_Qatari_municipal_elections
# /wiki/2003_Qatari_constitutional_referendum
# /wiki/Qatar_Armed_Forces
# /wiki/RAF
# /wiki/Gibraltar
# /wiki/Madrid
# /wiki/Brussels
# /wiki/Eurovision_Song_Contest_1976
# /wiki/Eurovision_Song_Contest_1992
# /wiki/Sou_fr%C3%A4i
# /wiki/Monique_Melsen
# /wiki/Ce_soir_je_t%27attendais
# /wiki/Un_peu_de_poivre,_un_peu_de_sel
# /wiki/Mich%C3%A8le_Torr
# /wiki/Monaco_in_the_Eurovision_Song_Contest_1959
# /wiki/Eurovision_Song_Contest_2007
# /wiki/Unsubstantial_Blues
# /wiki/Love_or_Leave
# /wiki/Lithuania_in_the_Eurovision_Song_Contest
# /wiki/Eurovision_Song_Contest_2009
# /wiki/Love_Symphony
# /wiki/Karmen_Stavec
# /wiki/Slovenia
# /wiki/State%27s_Attorney
# /wiki/Organized_crime
# /wiki/Broken_windows_theory
# /wiki/Ethnography
# /wiki/William_Foote_Whyte
# /wiki/University_of_Chicago
# /wiki/University_of_Oregon
# /wiki/University_of_Pennsylvania
# /wiki/Pro_Football_Hall_of_Fame
# /wiki/Jonathan_Ogden
# /wiki/Isaac_Bruce
# /wiki/Carl_Eller
# /wiki/Jimmy_Conzelman
# /wiki/Bulldog_Turner
# /wiki/Walter_Payton
# /wiki/Governor_of_Illinois
# /wiki/Governor_of_Rhode_Island
# /wiki/Little_Compton,_Rhode_Island
# /wiki/1890_United_States_Census
# /wiki/Southern_United_States
# /wiki/Bank_of_America
# /wiki/Net_income
# /wiki/Matching_principle
# /wiki/P%26L
# /wiki/Governmental_accounting
# /wiki/Cost_of_goods_sold
# /wiki/Liability_(financial_accounting)
# /wiki/Revenue_recognition
# /wiki/Deferred_income
# /wiki/Software_license
# /wiki/Terms_of_service
# /wiki/Internet_privacy
# /wiki/Spyware
# /wiki/Technical_support
# /wiki/Google_Book_Search
# /wiki/Web_crawler
# /wiki/Bingbot
# /wiki/Web_indexing
# /wiki/Natural_language_search_engine
# /wiki/Rule-based_machine_translation
# /wiki/Dictionary-based_machine_translation
# /wiki/Rule-based_machine_translation
# /wiki/JSTOR_(identifier)
# /wiki/Ithaka_Harbors
# /wiki/JSTOR
# /wiki/Project_MUSE
# /wiki/Peabody_Institute_Library
# /wiki/Johns_Hopkins
# /wiki/Maryland
# /wiki/Languages_of_the_United_States
# /wiki/Potawatomi_language
# /wiki/Aspiration_(phonetics)
# /wiki/Phonetics
# /wiki/Fourier_transform
# /wiki/Henri_Poincar%C3%A9
# /wiki/Hendrik_Lorentz
# /wiki/Steven_Chu
# /wiki/Doi_(identifier)
# /wiki/ISO_31-12
# /wiki/MaxiCode
# /wiki/ISO_15897
# /wiki/ISO_22000
# /wiki/ISO/IEC_11404
# /wiki/ISO/IEC_6523
# /wiki/Universal_Remote_Console
# /wiki/ISO/IEC_27002
# /wiki/IEC_60870-6
# /wiki/EtherCAT
# /wiki/CAN_bus
# /wiki/PCI_Express
# /wiki/Industry_Standard_Architecture
# /wiki/Enhanced_Small_Disk_Interface
# /wiki/Fibre_Channel
# /wiki/Apple_Desktop_Bus
# /wiki/VMEbus
# /wiki/IEEE_1355
# /wiki/Bluetooth
# /wiki/Headset_(audio)
# /wiki/Plantronics
# /wiki/United_Airlines
# /wiki/Braathens_Regional_Aviation
# /wiki/China_Cargo_Airlines
# /wiki/Donghai_Airlines
# /wiki/Haikou
# /wiki/Haikou_Port_New_Seaport
# /wiki/China
# /wiki/President_of_the_People%27s_Republic_of_China
# /wiki/Liu_Yongqing
# /wiki/Hu-Wen_Administration
# /wiki/Liu_Yandong
# /wiki/Teng_Daiyuan
# /wiki/Ngapoi_Ngawang_Jigme
# /wiki/Chen_Kuiyuan
# /wiki/Wu_Xueqian
# /wiki/Fang_Yi
# /wiki/Zhang_Kehui
# /wiki/Xu_Kuangdi
# /wiki/Wang_Zhenyi
# /wiki/Wang_Zeshan
# /wiki/Gu_Chaohao
# /wiki/Liu_Dongsheng
# /wiki/GND_(identifier)
# /wiki/National_and_University_Library_in_Zagreb
# /wiki/National_library
# /wiki/Louis_XI_of_France
# /wiki/Henry_III_of_France
# /wiki/French_franc
# /wiki/Blaise_Pascal
# /wiki/Jean-Jacques_Rousseau
# /wiki/Jean_Starobinski
# /wiki/SELIBR_(identifier)
# /wiki/MusicBrainz
# /wiki/CC-BY-NC-SA
# /wiki/Creative_Commons_NonCommercial_license
# /wiki/CC-BY
# /wiki/ISBN_(identifier)
# /wiki/ECMAScript
# /wiki/PHIGS
# /wiki/Film_speed
# /wiki/Field_camera
# /wiki/Linhof
# /wiki/Germany
# /wiki/JSTOR_(identifier)
# /wiki/PMC_(identifier)
# /wiki/Bibliometrics
# /wiki/Information_science
# /wiki/Law
# /wiki/Rule_of_law
# /wiki/Procedural_law
# /wiki/Energy_law
# /wiki/Hirsch_report
# /wiki/REN21
# /wiki/MENA
# /wiki/Shirvan
# /wiki/Geology_of_Azerbaijan
# /wiki/Shirvan
# /wiki/Persian_language
# /wiki/Romanization_of_Persian
# /wiki/%DB%8C
# /wiki/Kaph
# /wiki/Tashkil
# /wiki/Mashq
# /wiki/Mauritania
# /wiki/Botswana
# /wiki/Lobatse
# /wiki/Bokaa
# /wiki/Sikwane
# /wiki/Dikgonnye
# /wiki/Mochudi
# /wiki/Pilane_(Botswana)
# /wiki/Botswana
# /wiki/Pelagie_Islands
# /wiki/Saint_Pierre_and_Miquelon
# /wiki/Google_Books
# /wiki/Preservation_(library_and_archival_science)
# /wiki/Censorship
# /wiki/Bleep_censor
# /wiki/Spaghetti_Cat
# /wiki/Mike_Jerrick
# /wiki/WNYW
# /wiki/Melissa_Francis
# /wiki/Harvard_University
# /wiki/Massachusetts
# /wiki/Fin_whale
# /wiki/Kenai_Fjords_National_Park
# /wiki/Seward_Highway
# /wiki/Resurrection_Bay
# /wiki/Alaska_SeaLife_Center
# /wiki/1964_Alaska_earthquake
# /wiki/2011_Colorado_earthquake
# /wiki/Doi_(identifier)
# /wiki/NISO
# /wiki/CiNii_(identifier)
# /wiki/Terminologia_Histologica
# /wiki/Kinocilium
# /wiki/Fish_anatomy
# /wiki/Neural_arch
# /wiki/Pedicle_of_vertebral_arch
# /wiki/Spinal_canal
# /wiki/Neck_of_rib
# /wiki/Thoracic_inlet
# /wiki/Thoracic_cavity
# /wiki/Mesothelium
# /wiki/Lobe_(anatomy)
# /wiki/Thymus#Microanatomy
# /wiki/Humerus
# /wiki/Coracoid_process
# /wiki/Foundational_Model_of_Anatomy
# /wiki/RDFa
# /wiki/TriX_(serialization_format)
# /wiki/Schema.org
# /wiki/Reference_(computer_science)
# /wiki/Interval_arithmetic#Implementations
# /wiki/University_of_Karlsruhe
# /wiki/H%C3%B6llentalbahn_(Black_Forest)
# /wiki/Wiehre
# /wiki/Loretto_Baths
# /wiki/Geographic_coordinate_system
# /wiki/Equator
# /wiki/Ecuador
# /wiki/Jorge_Carrera_Andrade
# /wiki/BNF_(identifier)
# /wiki/Lyc%C3%A9e_Rodin
# /wiki/Bus_(RATP)
# /wiki/Tramways_in_%C3%8Ele-de-France
# /wiki/Belleville_funicular_tramway
# /wiki/Concession_(contract)
# /wiki/Property_abstract
# /wiki/Property_cycle
# /wiki/Real_estate_in_Pakistan
# /wiki/History_of_Pakistan
# /wiki/History_of_Indonesia
# /wiki/East_Timor
# /wiki/1999_East_Timorese_crisis
# /wiki/Arab_Spring
# /wiki/The_New_York_Times
# /wiki/Haimun
# /wiki/L%C3%BCshunkou
# /wiki/Fuxin_Mongol_Autonomous_County
# /wiki/Benxi
# /wiki/Ji%27an,_Jilin
# /wiki/Yemaek
# /wiki/Shuowen_Jiezi
# /wiki/Spelling_in_Gwoyeu_Romatzyh
# /wiki/Voiceless_velar_plosive
# /wiki/Voice_(phonetics)
# /wiki/Voiced_palatal_implosive
# /wiki/Voiceless_velar_approximant
# /wiki/Voiced_velar_lateral_approximant
# /wiki/Pharyngeal_consonant
# /wiki/Labiodental_consonant
# /wiki/Voiced_linguolabial_nasal
# /wiki/Voiceless_uvular_trill
# /wiki/Voiced_uvular_nasal
# /wiki/Voiceless_palatal_lateral_affricate
# /wiki/Retroflex_nasal_click
# /wiki/Tenuis_consonant
# /wiki/Semivowel
# /wiki/Linguolabial_consonant
# /wiki/Sibilant
# /wiki/Sulcalization
# /wiki/Rhotic_consonant
# /wiki/Place_of_articulation
# /wiki/Bilabial_consonant
# /wiki/Near-open_central_vowel
# /wiki/Bilabial_nasal_click
# /wiki/Voiceless_retroflex_flap
# /wiki/Labio-palatalization
# /wiki/Nasal_palatal_approximant
# /wiki/Voiceless_uvular_fricative
# /wiki/Alveolar_consonant
# /wiki/Near-open_front_unrounded_vowel
# /wiki/Voiceless_alveolar_tap
# /wiki/Close_back_rounded_vowel
# /wiki/New_York_City_English
# /wiki/The_Observer
# /wiki/CBBC_(TV_channel)
# /wiki/Elisabeth_Sladen
# /wiki/Jon_Pertwee
# /wiki/Sean_Pertwee
# /wiki/Clarissa_(TV_series)
# /wiki/Miniseries
# /wiki/Revised_Romanization_of_Korean
# /wiki/Cyrillization_of_Korean
# /wiki/Transliteration
# /wiki/List_of_ISO_transliterations
# /wiki/GOST_16876-71
# /wiki/Romanization_of_Hebrew
# /wiki/Informal_romanizations_of_Cyrillic
# /wiki/Russian_Chat_Alphabet
# /wiki/Gyaru-moji
# /wiki/Latin_alphabet
# /wiki/Uzbekistan
# /wiki/Tashkent
# /wiki/Piskent_District
# /wiki/Bekabad
# /wiki/Nukus
# /wiki/Qorako%E2%80%98l
# /wiki/Chirchiq
# /wiki/Andijan
# /wiki/Ziyarat#Iran
# /wiki/Seyyed_Hossein_Borujerdi
# /wiki/BNF_(identifier)
# /wiki/Charles_VII_of_France
# /wiki/Catherine_of_Valois,_Countess_of_Charolais
# /wiki/Isabella_of_Portugal,_Duchess_of_Burgundy
# /wiki/Ghent
# /wiki/Ghent%E2%80%93Terneuzen_Canal
# /wiki/Terneuzen
# /wiki/Zaamslag
# /wiki/Templar_Knights
# /wiki/Latin_Empire
# /wiki/New_Fortress
# /wiki/Deo_Optimo_Maximo
# /wiki/Doi_(identifier)
# /wiki/ISO_2
# /wiki/O-ring
# /wiki/Back-up_ring
# /wiki/Nitrile
# /wiki/Doi_(identifier)
# /wiki/Request_for_Comments
# /wiki/Internet_Engineering_Steering_Group
# /wiki/Internet
# /wiki/Online_gambling
# /wiki/Horse_racing
# /wiki/Wayback_Machine
# /wiki/Progressive_web_applications
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d656de7aa0e6> in <module>
#       3     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#       4     print(newArticle)
# ----> 5     links = getLinks(newArticle)
#
# <ipython-input-21-fdd0234eb0b3> in getLinks(articleUrl)
#       1 def getLinks(articleUrl):
#       2     html = urlopen('http://en.wikipedia.org'+articleUrl)
# ----> 3     bsObj = BeautifulSoup(html, 'html.parser')
#       4     return bsObj.find('div', {'id': 'bodyContent'}).findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     307
#     308         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 309             markup = markup.read()
#     310         elif len(markup) <= 256 and (
#     311                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in read(self, amt)
#     463
#     464             if self.chunked:
# --> 465                 return self._readall_chunked()
#     466
#     467             if self.length is None:
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in _readall_chunked(self)
#     573                 if chunk_left is None:
#     574                     break
# --> 575                 value.append(self._safe_read(chunk_left))
#     576                 self.chunk_left = 0
#     577             return b''.join(value)
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in _safe_read(self, amt)
#     610         IncompleteRead exception can be used to detect the problem.
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#     614             raise IncompleteRead(data, amt-len(data))
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python38\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python38\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(links)
# Out:
# 179

# %% [markdown]
# ### 데이터 수집

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()

def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org'+pageUrl)
    bsObj = BeautifulSoup(html, 'html.parser')
    for link in bsObj.findAll('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                # 새 페이지를 발견
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/File:A_coloured_voting_box.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Metropolitan_statistical_area
# /wiki/List_of_metropolitan_statistical_areas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c1969d59843f> in <module>
#      17                 pages.add(newPage)
#      18                 getLinks(newPage)
# ---> 19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-27-c1969d59843f> in getLinks(pageUrl)
#       8     global pages
#       9     html = urlopen('http://en.wikipedia.org'+pageUrl)
# ---> 10     bsObj = BeautifulSoup(html, 'html.parser')
#      11     for link in bsObj.findAll('a', href=re.compile('^(/wiki/)')):
#      12         if 'href' in link.attrs:
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~\AppData\Local\Programs\Python\Python38\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~\AppData\Local\Programs\Python\Python38\lib\html\parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     149         #print("START", name)
#     150         sourceline, sourcepos = self.getpos()
# --> 151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
#     153             sourcepos=sourcepos
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     694         """
#     695         # print("Start tag %s: %s" % (name, attrs))
# --> 696         self.endData()
#     697
#     698         if (self.parse_only and len(self.tagStack) <= 1
#
# d:\project\crawling-tuto-oreily\env\lib\site-packages\bs4\__init__.py in endData(self, containerClass)
#     550             # nothing but ASCII spaces, replace it with a single space
#     551             # or newline.
# --> 552             if not self.preserve_whitespace_tag_stack:
#     553                 strippable = True
#     554                 for i in current_data:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 전체 사이트에서 데이터 수집

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org'+ pageUrl)
    bsObj = BeautifulSoup(html, 'html.parser')
    try :
        print(bsObj.h1.get_text())
        print(bsObj.find(id = 'mw-content-text').findAll('p'[0]))
        print(bsObj.find(id='ca-edit'.find('span').find('a').attrs['href']))
    except AttributeError:
        print('this page is missing something! No worries though!')
    for link in bsObj.findAll('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newPage = link.attrs['href']
                print('------------\n'+newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# inger’s South Africa campaign. A more detailed interview in South Africa’s <a class="external text" href="https://www.dailymaverick.co.za/article/2017-07-31-bell-pottinger-fallout-continues-as-hearings-set-to-kick-off-in-uk/" rel="nofollow"><i>Daily Maverick</i></a> quotes Veribo’s CEO expressing the same view and deflecting all responsibility for the campaign onto Bell Pottinger.
# </p>, <p>Bell Pottinger has had a long history with Wikipedia.  <a class="external text" href="https://www.independent.co.uk/news/uk/politics/caught-on-camera-top-lobbyists-boasting-how-they-influence-the-pm-6272760.html" rel="nofollow">In a videotaped undercover interview</a> by the <i><a href="/wiki/Bureau_of_Investigative_Journalism" title="Bureau of Investigative Journalism">Bureau of Investigative Journalism</a></i>,  Bell Pottinger revealed that it "sorts" Wikipedia coverage of its clients with a team of employees, and also employs other "dark arts" for its clients.
# </p>, <p>When its South African campaign was exposed in 2017, Bell Pottinger immediately began losing clients and employees and the firm quickly collapsed.
# </p>, <p>Wikipedia administrator <span class="plainlinks"><a class="external text" href="https://en.wikipedia.org/wiki/User:OhanaUnited">OhanaUnited</a></span> is a resident of Ontario and  knows about WE and the recent scandal. He told <i>The Signpost</i> that when he first saw the edit with the Dropbox link he thought "oh, someone's finally going to expand this article on this worthy initiative." But the editor must have been new and unfamiliar with Wikipedia’s referencing practices. "How many people prepare it (their edit) as .docx and upload to Dropbox? … I was pretty sure it's undisclosed paid editing since the Dropbox file path mentioned 'Clients' but my editing areas don't typically come across paid editing and I needed second pair of eyes to look at it" so he asked about the edit at the <a class="mw-redirect" href="/wiki/Wikipedia:COIN" title="Wikipedia:COIN">conflict of interest noticeboard</a>.
# </p>, <p>Wikipedia administrator <span class="plainlinks"><a class="external text" href="https://en.wikipedia.org/wiki/User:Newslinger">Newslinger</a></span> guided <i>The Signpost</i> through this sock puppet investigation, to the extent permitted by Wikipedia rules.
# </p>, <p>Many undisclosed paid editing cases involve the abuse of multiple accounts, also known as <a href="/wiki/Wikipedia:Sockpuppetry" title="Wikipedia:Sockpuppetry">sockpuppets</a>. These editors may have particular behaviors that can be observed among more than one of their accounts. This behavioral evidence can be submitted as a sockpuppet investigation (SPI) to trace the extent of the possible abuse.
# </p>, <p>In an SPI, the editing history of the editors under examination are probed to determine if at least two of these accounts are operated by the same individual and also looks for potential connections to other accounts. All SPIs include a review of the available behavioral evidence and some SPIs also involve administrators known as checkusers who can inspect site logs not revealed publicly on Wikipedia, called technical evidence. A checkuser can only examine technical evidence if there is adequate behavioral evidence.
# </p>, <p>Few investigations have "smoking gun" evidence as strong as the Dropbox links in the Percepto case. The first link was discovered by chance by an editor not usually involved in paid editing investigations: a Microsoft Windows file path that was accidentally included by editor Issack.build in a 3 June 2019 edit. The link revealed Ruslan Baisarov as one of Veribo's "Active Clients restored". The edit was tagged as a visual edit, which means that Issack.build most likely drafted the content in a word processor before copying and pasting it into the Wikipedia article.
# </p>, <p>The Wikipedia search feature was used to find all traces of Veribo in Wikipedia articles. Another Dropbox link from Veribo was found: on 16 June 2019, MarthaLetter's link identified the article Me to We as another one of Veribo's "Active Clients restored" that had a "wiki page" in "phase 3" of some operation.
# </p>, <p>Combined, these two links showed that Veribo was associated with at least two accounts that engaged in undisclosed paid editing and a search of technical evidence began. Five other accounts showed behavioral evidence of being connected to the first two accounts and technical evidence resulted in the blocking of 12 sock puppet accounts.
# </p>, <p>The strength of the behavioral and technical evidence in this investigation made it highly unlikely that these accounts were framed in a "joe job", which are usually related to trolls rather than paid editors.
# </p>, <p>The edits made by accounts blocked for their connection to Percepto/Veribo provide a window into the world of sophisticated paid advocacy on Wikipedia by a firm which is willing to take on politically connected assignments.
# </p>, <p>These editors created some articles and  influenced the content of other articles related to the WE charity which is now being investigated in a scandal involving Canadian Prime Minister Justin Trudeau. While we haven’t presented any evidence that Trudeau knew about Percepto, the charity WE should have been able to find enough information about the type of online reputation managers that they employed just by reading Percepto’s website.
# </p>, <p>Percepto or the editors connected to them were involved in editing in three areas of concern to the public. Where does this paid advocacy editing leave Wikipedia’s reputation for accuracy?
# </p>, <p>Some Wikipedia editors might think that the Percepto editors were only caught because they made two silly mistakes and were incompetent. Other Wikipedians know, much to their chagrin, that it is surprisingly easy to unknowingly reveal identifying information while editing. Percepto editors may be back - there is apparently a lot of money to be made in this business.  While it may take some time to discover any new edits they make, sooner or later they would likely be discovered again. Clients of ORM firms should be aware of this.
# </p>, <p>Of course there are many companies, frauds, grifters, and kleptocrats that have things to hide and would like to use similar ORM firms to edit Wikipedia. Some of them may be willing to spend much more money on it than the WE charity could.  Completely stopping paid advocacy on Wikipedia may be an impossible task, but it is a task that Wikipedians continue to diligently work on.
# </p>, <p><i>The Signpost</i> will continue to cover online reputation management firms. If you have any tips that can be documented on how these firms operate on Wikipedia, please contact us <a href="/wiki/Special:EmailUser/Smallbones" title="Special:EmailUser/Smallbones">here</a>.
# </p>, <p>The WE charity and Percepto were contacted to request comments on this story.  WE responded that they would get back within 48 hours. Percepto did not respond before deadline.  <i>The Signpost</i> will update this story with any replies from them.
# </p>, <p><br/>
# </p>, <p><br/>
# </p>, <p>it doesn't mean a story must include the author's entry point.
# It was a BAD BAD bad idea to disclose how sockpuppet investigation works and how the paid editors were sniffed out. Next ones will smarten up . <a href="/wiki/User:Staszek_Lem" title="User:Staszek Lem">Staszek Lem</a> (<a href="/wiki/User_talk:Staszek_Lem" title="User talk:Staszek Lem">talk</a>) 23:29, 27 September 2020 (UTC)
# </p>, <p>Tiny critique: I had to read the part about Trudeau's mother twice, to infer that she was paid by the WE charity. The article just states she was paid to speak. Maybe a small edit there is in order? For the rest I agree with <a href="/wiki/User:Indy_beetle" title="User:Indy beetle">User:Indy beetle</a> calling this an excellent piece. Since I started reading the signpost I've been impressed every time about the quality of the special reports! <a href="/wiki/User:Dutchy45" title="User:Dutchy45">Dutchy45</a> (<a href="/wiki/User_talk:Dutchy45" title="User talk:Dutchy45">talk</a>) 16:04, 28 September 2020 (UTC)
# </p>, <p><br/>
# </p>]
# this page is missing something! No worries though!
# ------------
# /wiki/Wikipedia:Wikipedia_Signpost/2020-09-27
# Wikipedia:Wikipedia Signpost/2020-09-27
# [<p class="mw-empty-elt">
# </p>]
# this page is missing something! No worries though!
# ------------
# /wiki/Wikipedia:Wikipedia_Signpost/2020-09-27/News_and_notes
# Wikipedia:Wikipedia Signpost/2020-09-27/News and notes
# [<p><br/>
# </p>, <p>A <a class="extiw" href="https://meta.wikimedia.org/wiki/Small_wiki_audit/Malagasy_Wiktionary" title="m:Small wiki audit/Malagasy Wiktionary">small wiki audit of the Malagasy Wiktionary</a> found that the wiktionary, which has the second largest number of entries (over <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Manokana:Statistika" title="mg:wikt:Manokana:Statistika">6,103,961</a>), has had a large number of their pages automatically translated.  Bot-Jagwar is a bot account run by <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Mpikambana:Jagwar" title="mg:wikt:Mpikambana:Jagwar">Jagwar</a>, the <a class="external text" href="https://mg.wiktionary.org/w/index.php?title=Manokana:Lisitran%27ny_mpikambana&amp;group=sysop">sole admin who has made edits</a>. On the project, his bot has made <a class="extiw" href="https://meta.wikimedia.org/wiki/Requests_for_comment/Large-scale_errors_at_Malagasy_Wiktionary" title="m:Requests for comment/Large-scale errors at Malagasy Wiktionary">more than 22 million edits</a> (and counting). Jagwar also has a secondary bot account, <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Mpikambana:Bot-Jagwar_II" title="mg:wikt:Mpikambana:Bot-Jagwar II">Bot-Jagwar II</a> which has made a further <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Special:Contributions/Bot-Jagwar_II" title="mg:wikt:Special:Contributions/Bot-Jagwar II">6,976 edits</a>. Another major bot contributing to mg.wikt, making the exact same type of edit, is <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Mpikambana:Ikotobaity" title="mg:wikt:Mpikambana:Ikotobaity">Ikotobaity</a>, with 2,456,748 edits run by <a class="extiw" href="https://mg.wikipedia.org/wiki/wikt:Mpikambana:Lohataona" title="mg:wikt:Mpikambana:Lohataona">Lohataona</a> until 2017; the bot has been inactive since 20 October 2017. These three bots have created <a class="external text" href="https://quarry.wmflabs.org/query/47927" rel="nofollow">6,076,769 new mainspace pages</a>, which is 99.23% of all mainspace pages on mg.wikt. (Jagwar also ran bot edits on his main account, so the true number of bot-created entries is likely 50,000 higher.)
# </p>, <p>In <a class="external text" href="https://www.terakasorotany.com/?p=143" rel="nofollow">this blog post</a>, Jagwar detailed the history of his bot and mg.wikt. The bot began editing in 2010, at a rate of 50,000 edits per day, initially simply importing foreign words from other wiktionaries. After the wiki reached 200,000 pages in 2011, he wrote a script that "upload[ed] the word forms of that language", and propelled Malagasy Wiktionary to be the third largest. In 2012, Jagwar developed a more refined script. He uses NLP and automated translation in order to generate new entries, with no human intervention nor oversight. In the blog post, he wrote that translation errors were estimated at &lt;5%, though he had "no precise idea" of it.
# </p>, <p>There is no active editing community, and Jagwar is the sole active admin on the site. Jagwar himself has only made 6 edits in the last 90 days, of which only 3 were in mainspace. The audit noted that there are various mistakes in the entries. Of a random survey of 100  non-Malagasy entries, the auditor concluded that 49 were "unusable", 29 "partially usable", and only 22 were "fully correct and usable" (though they may still have minor errors). Of Malagasy entries, the report noted that:
# </p>, <p>There are 41,902 entries categorised as lacking any definition, most of which seem to be Malagasy entries, and around 30,000 of which are the result of the definitions being removed due to copyright violation many years ago. Although there are 1,150,182 Malagasy entries in total, most of these are inflected forms, which can generally be safely created by bots. These definitionless entries are not strictly speaking incorrect, but a definition is the most central function of a dictionary, so these entries fail to be a useful part of the dictionary as a whole.</p>, <p>The bots also ran <a class="extiw" href="https://chr.wikipedia.org/wiki/wikt:Special:Contributions/Bot-Jagwar" title="chr:wikt:Special:Contributions/Bot-Jagwar">218,156 edits at chr.wikt</a> from 2012 to 2014 and <a class="extiw" href="https://ku.wikipedia.org/wiki/wikt:Special:Contributions/Bot-Jagwar" title="ku:wikt:Special:Contributions/Bot-Jagwar">127,389 edits at ku.wikt</a> from 2012 to 2013. The audit concluded that "Even an editing community of the size of the biggest Wiktionary, en.wikt, would not be able to clean up after these bots by hand". It strongly recommended deleting all non-Malagasy entries, removing translation sections, and telling the bot owners to cease automated creation of entries, and weakly recommended deleting all definition-less entries. <small> – adapted by <a href="/wiki/User:Eddie891" title="User:Eddie891">Eddie891</a> from <a class="extiw" href="https://meta.wikimedia.org/wiki/Requests_for_comment/Large-scale_errors_at_Malagasy_Wiktionary" title="m:Requests for comment/Large-scale errors at Malagasy Wiktionary">Large-scale errors at Malagasy Wiktionary</a>, written by <a href="/wiki/User:Metaknowledge" title="User:Metaknowledge">Metaknowledge</a>, with help from <a href="/wiki/User:Surjection" title="User:Surjection">Surjection</a>, <a href="/wiki/User:AryamanA" title="User:AryamanA">AryamanA</a>, <a href="/wiki/User:Erutuon" title="User:Erutuon">Erutuon</a>, and <a href="/wiki/User:Smashhoof" title="User:Smashhoof">Smashhoof</a>, along with input from a fluent speaker of Malagasy who wishes to remain anonymous.</small>
# </p>, <p>A <a href="/wiki/Special:PermanentLink/976895063#Deprecate_parenthetical_citations" title="Special:PermanentLink/976895063">Request for Comment (RfC) to deprecate the inline parenthetical citation style</a> was closed by <a href="/wiki/User:Seraphimblade" title="User:Seraphimblade">Seraphimblade</a> on 5 September as having reached consensus "that inline parenthetical referencing should be deprecated". The RFC, which was begun by <a href="/wiki/User:CaptainEek" title="User:CaptainEek">CaptainEek</a> on 5 August, drew a large amount of attention and discussion. A <a class="mw-redirect" href="/wiki/Wikipedia:WLN" title="Wikipedia:WLN">watchlist notice</a> for the RFC was <a href="/wiki/Special:Diff/975679275" title="Special:Diff/975679275">placed</a> on 29 August after <a href="/wiki/Special:PermanentLink/975679431" title="Special:PermanentLink/975679431">a discussion</a> determined that it was a sufficiently high-profile RFC.
# </p>, <p>In closing the discussion, Seraphimblade noted that roughly 71% of the community had supported the proposal and that there was only consensus to deprecate "parenthetical style citations directly inlined into articles", rather than {{<a class="mw-redirect" href="/wiki/Template:Harv" title="Template:Harv">harv</a>}} style-references in <code>&lt;ref&gt;&lt;/ref&gt;</code> tags. The RFC led to the <a class="mw-redirect" href="/wiki/Wikipedia:PAREN" title="Wikipedia:PAREN">WP:PAREN</a> and <a class="mw-redirect" href="/wiki/Wikipedia:CITEVAR" title="Wikipedia:CITEVAR">WP:CITEVAR</a> guidelines needing an update, though as of <i>The Signpost</i><span class="nowrap" style="padding-left:0.1em;">'</span>s publication deadline, what the update would look like was still under discussion. Before the RfC, CITEVAR specifically stated that "editors should not attempt to change an article's established citation style merely on the grounds of personal preference" and cited a <a href="/wiki/Wikipedia:Requests_for_arbitration/Sortan#Preferred_styles" title="Wikipedia:Requests for arbitration/Sortan">2006 Arbitration Committee decision</a> that "Wikipedia does not mandate styles in many different areas", including citation style. <small> – <a href="/wiki/User:Eddie891" title="User:Eddie891">E</a></small>
# </p>, <p><span class="template-ping">@<a href="/wiki/User:Bri" title="User:Bri">Bri</a> and <a href="/wiki/User:Smallbones" title="User:Smallbones">Smallbones</a>:</span> in <style data-mw-deduplicate="TemplateStyles:r886049556">.mw-parser-output .inline-quote-talk{font-family:Georgia,"DejaVu Serif",serif;color:#008560;quotes:none}.mw-parser-output .inline-quote-talk-italic{font-family:inherit;font-style:italic}.mw-parser-output .inline-quote-talk-marks{quotes:"\"""\""}</style><q class="inline-quote-talk">While most participants in the RfA cited Wikipedia's common name policy</q> is RfA meant to be RfC or RM? --<a href="/wiki/User:DannyS712" title="User:DannyS712">DannyS712</a> (<a href="/wiki/User_talk:DannyS712" title="User talk:DannyS712">talk</a>) 22:49, 27 September 2020 (UTC)
# </p>, <p>As <span class="plainlinks"><a class="external text" href="https://en.wikipedia.org/wiki/User:Jayen466">Jayen466</a></span> said: <link href="mw-data:TemplateStyles:r886049556" rel="mw-deduplicated-inline-style"/><q class="inline-quote-talk">"Whatever Wikipedia as a community is doing, it is more of a vehicle for contributors' self-indulgence than it is a concerted endeavour to bring free knowledge to the world."</q> Our community coddles editors like Jagwar and AmaryllisGardener because that's what we're really about, which is sad. <span class="nowrap" style="font-family:copperplate gothic light;"><a href="/wiki/User:Chris_troutman" title="User:Chris troutman"><span style="color:#345">Chris Troutman</span></a> (<a href="/wiki/User_talk:Chris_troutman" title="User talk:Chris troutman"><span style="color:#345">talk</span></a>)</span> 00:54, 28 September 2020 (UTC)
# </p>, <p>This is a misleading and not very useful metric, as it includes bot and spider views.  Admittedly, the fault largely lies with the Foundation's Wikistats 2.0 tool, which mentions this issue in the small print - "In this data we try to separate bot traffic and focus on human user page views" - but nevertheless presents the total views as the default. The trick for following that "focus on human user page views" recommendation is to click "Split by agent type" in the left sidebar and then use the checkboxes to select the right combination of metric components. (Also, while the linked data documentation fails to mention it, be aware that a substantial amount of views were reclassified as "automated" starting in May 2020.)
# </p>, <p>Separately, while it seems indeed true that there was a coronavirus-related traffic peak around April and May, pageviews <a href="/wiki/File:Wikimedia_pageviews_year-over-year_comparison_(since_May_2013).png" title="File:Wikimedia pageviews year-over-year comparison (since May 2013).png">drop considerably from April to August every year</a> due to seasonal changes. So the comparison in the article ("... down from the recent high in April ...") is not very meaningful.
# </p>, <p>Regard, <a href="/wiki/User:HaeB" title="User:HaeB">HaeB</a> (<a href="/wiki/User_talk:HaeB" title="User talk:HaeB">talk</a>) 02:07, 28 September 2020 (UTC)
# </p>, <p>That's a rather usual name for a tropical cyclone... --<a href="/wiki/User:Guy_Macon" title="User:Guy Macon">Guy Macon</a> (<a href="/wiki/User_talk:Guy_Macon" title="User talk:Guy Macon">talk</a>) 06:35, 28 September 2020 (UTC)
# </p>, <p><br/>
# </p>]
# this page is missing something! No worries though!
# ------------
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/2020-09-27
# Wikipedia:Wikipedia Signpost/Archives/2020-09-27
# []
# this page is missing something! No worries though!
# ------------
# /wiki/Wikipedia:Wikipedia_Signpost/Archives
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-96946e69dd56> in <module>
#      21                 pages.add(newPage)
#      22                 getLinks(newPage)
# ---> 23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# ...
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#      20                 print('------------\n'+newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-12-96946e69dd56> in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
#       7     global pages
# ----> 8     html = urlopen('http://en.wikipedia.org'+ pageUrl)
#       9     bsObj = BeautifulSoup(html, 'html.parser')
#      10     try :
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in http_open(self, req)
#    1377
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#    1381     http_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\AppData\Local\Programs\Python\Python38\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# 파이썬 함수를 결합하면 다양한 웹 스크랩핑을 실행하는 코드를 쉽게 만들 수 있고, 이는 50줄도 안 되는 코드로도 충분히 가능합니다.

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

# %%
pages = set()
random.seed(datetime.datetime.now())

# %%
# 페이지에서 발견된 내부 링크를 모두 목록으로 만듭니다. 
def getInernalLinks(bsObj, includeUrl):
    includeUrl = urlparse(includeUrl).scheme+"://"+urlparse(includeUrl).netloc
    internalLinks = []
    # /로 시작하는 링크를 모두 찾습니다. 
    for link in bsObj.findAll('a', href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks

# %%
# 페이지에서 발견된 외부 링크를 모두 목록으로 만듭니다. 
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
    # 현재 URL을 포함하지 않으면서 http나 www로 시작하는 링크를 모두 찾습니다. 
    for link in bsObj.findAll('a', href=re.compile('^(http|www)((?!"+excludeUrl+").)*$')):
        if link.attrs['href'] is not None:
            if link.attrs not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

# %%
def splitAddress(address):
    addressParts = address.replace("https://", "").split("/")
    return addressParts

# %%
def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bsObj, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        domain = urlparse(startingPage).scheme+'://'+urlparse(startingPage).netloc
        internalLinks = getInternalLinks(bsObj, domain)
        return getRandomExternalLink(internalLinks[random.randint(0, len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]

# %%
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('random external link is: '+externalLink)
    followExternalOnly(externalLink)

# %%
followExternalOnly('http://oreilly.com')
# Out:
# random external link is: https://learning.oreilly.com/library/view/analytical-skills-for/9781492060932/
# random external link is: https://learning.oreilly.com/library/view/analytical-skills-for/9781492060932/ch06.html#idm46359805186968
# random external link is: https://www.oreilly.com
# random external link is: https://www.oreilly.com/online-learning/feature-answers.html
# random external link is: https://www.youtube.com/user/OreillyMedia
# random external link is: https://www.youtube.com/about/copyright/
# random external link is: https://www.instagram.com/youtube/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9f1254de227e> in <module>
# ----> 1 followExternalOnly('http://oreilly.com')
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
# ----> 4     followExternalOnly(externalLink)
#
# <ipython-input-37-6e95b1a7f437> in followExternalOnly(startingSite)
#       1 def followExternalOnly(startingSite):
# ----> 2     externalLink = getRandomExternalLink(startingSite)
#       3     print('random external link is: '+externalLink)
#       4     followExternalOnly(externalLink)
#
# <ipython-input-36-820c1bb263e3> in getRandomExternalLink(startingPage)
#       5     if len(externalLinks) == 0:
#       6         domain = urlparse(startingPage).scheme+'://'+urlparse(startingPage).netloc
# ----> 7         internalLinks = getInternalLinks(bsObj, domain)
#       8         return getRandomExternalLink(internalLinks[random.randint(0, len(internalLinks)-1)])
#       9     else:
#
# NameError: name 'getInternalLinks' is not defined

# %%
# 사이트에서 찾은 외부 URL을 모두 리스트로 수집
allExtLinks = set()
allIntLinks = set()

def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    bsObj = BeautifulSoup(html, 'html.parser')
    internalLinks = getInernalLinks(bsObj, splitAddress(domain)[0])
    externalLinks = getExternalLinks(bsObj, splitAddress(domain)[0])

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link == '/':
            link = domain 
        elif link[0:2] == '//':
            link = 'http:' + link
        elif link[0:1] == '/':
            link = domain + link
        
        if link not in allIntLinks:
            print('About to get link: ' + link)
            allIntLinks.add(link)
            getAllExternalLinks(link)

domain = 'http://oreilly.com'
getAllExternalLinks(domain)
# Out:
# https://www.oreilly.com
# https://learning.oreilly.com/accounts/login-check/
# https://www.oreilly.com/online-learning/try-now.html
# https://www.oreilly.com/online-learning/teams.html
# https://www.oreilly.com/online-learning/individuals.html
# https://www.oreilly.com/online-learning/features.html
# https://www.oreilly.com/online-learning/feature-certification.html
# https://www.oreilly.com/online-learning/intro-interactive-learning.html
# https://www.oreilly.com/online-learning/live-online-sessions.html
# https://www.oreilly.com/online-learning/feature-answers.html
# https://www.oreilly.com/whats-new.html
# https://www.oreilly.com/content-marketing-solutions.html
# https://www.oreilly.com/online-learning/business.html
# https://www.oreilly.com/online-learning/enterprise.html
# https://www.oreilly.com/online-learning/article-answers.html
# https://learning.oreilly.com/library/view/innovative-tableau/9781492075646/
# https://learning.oreilly.com/live-training/courses/python-data-science-full-throttle-with-paul-deitel-introductory-artificial-intelligence-ai-big-data-and-cloud-case-studies/0636920410720/
# https://learning.oreilly.com/library/view/analytical-skills-for/9781492060932/
# https://learning.oreilly.com/library/view/dynamic-reteaming-2nd/9781492061281/
# https://learning.oreilly.com/library/view/21-technologies-for/9781492090298/
# https://learning.oreilly.com/library/view/coronavirus-and-business/9781647820404/
# https://learning.oreilly.com/library/view/kubernetes-operators/9781492048039/
# https://learning.oreilly.com/live-training/courses/oreilly-infrastructure-ops-superstream-series/0636920410027/
# https://learning.oreilly.com/library/view/chaos-engineering/9781492043850/
# https://learning.oreilly.com/register/
# https://learning.oreilly.com/team-setup/
# https://www.oreilly.com/online-learning/business.html?team=large
# https://twitter.com/oreillymedia
# https://www.facebook.com/OReilly/
# https://www.linkedin.com/company/oreilly-media
# https://www.youtube.com/user/OreillyMedia
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# About to get link: http:///about/
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-40-8ad711e72bfc> in <module>
#      27
#      28 domain = 'http://oreilly.com'
# ---> 29 getAllExternalLinks(domain)
#
# <ipython-input-40-8ad711e72bfc> in getAllExternalLinks(siteUrl)
#      24             print('About to get link: ' + link)
#      25             allIntLinks.add(link)
# ---> 26             getAllExternalLinks(link)
#      27
#      28 domain = 'http://oreilly.com'
#
# <ipython-input-40-8ad711e72bfc> in getAllExternalLinks(siteUrl)
#       4
#       5 def getAllExternalLinks(siteUrl):
# ----> 6     html = urlopen(siteUrl)
#       7     bsObj = BeautifulSoup(html, 'html.parser')
#       8     internalLinks = getInernalLinks(bsObj, splitAddress(domain)[0])
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     520         for processor in self.process_request.get(protocol, []):
#     521             meth = getattr(processor, meth_name)
# --> 522             req = meth(req)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
#
# ~\AppData\Local\Programs\Python\Python38\lib\urllib\request.py in do_request_(self, request)
#    1272         host = request.host
#    1273         if not host:
# -> 1274             raise URLError('no host given')
#    1275
#    1276         if request.data is not None:  # POST
#
# URLError: <urlopen error no host given>

# %% [markdown]
# ## 스크래파이를 사용한 크롤링
