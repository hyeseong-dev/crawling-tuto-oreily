# %%
# !pip install scrapy
# Out:
# temadapter, zope.interface, w3lib, jmespath, parsel, itemloaders, constantly, incremental, Automat, hyperlink, PyHamcrest, Twisted, protego, pyasn1, pyasn1-modules, service-identity, queuelib, scrapy
#     Running setup.py install for PyDispatcher: started
#     Running setup.py install for PyDispatcher: finished with status 'done'
#     Running setup.py install for Twisted: started
#     Running setup.py install for Twisted: finished with status 'error'
#     copying src\twisted\internet\_newtls.py -> build\lib.win-amd64-3.8\twisted\internet
#     copying src\twisted\internet\_pollingfile.py -> build\lib.win-amd64-3.8\twisted\internet
#     copying src\twisted\internet\_posixserialport.py -> build\lib.win-amd64-3.8\twisted\internet
#     copying src\twisted\internet\_posixstdio.py -> build\lib.win-amd64-3.8\twisted\internet
#     copying src\twisted\internet\_producer_helpers.py -> build\lib.win-amd64-3.8\twisted\internet
# ...

# %%
import scrapy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-40a98f9a83be> in <module>
# ----> 1 import scrapy
#
# ModuleNotFoundError: No module named 'scrapy'

# %%
# !pip freeze
# Out:
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==20.2.0
# Automat==20.2.0
# backcall==0.2.0
# beautifulsoup4==4.9.3
# bleach==3.2.1
# certifi==2020.6.20
# cffi==1.14.3
# chardet==3.0.4
# colorama==0.4.4
# constantly==15.1.0
# cryptography==3.1.1
# cssselect==1.1.0
# decorator==4.4.2
# defusedxml==0.6.0
# entrypoints==0.3
# hyperlink==20.0.1
# idna==2.10
# incremental==17.5.0
# ipykernel==5.3.4
# ipython==7.18.1
# ipython-genutils==0.2.0
# itemadapter==0.1.1
# itemloaders==1.0.3
# jedi==0.17.2
# Jinja2==2.11.2
# jmespath==0.10.0
# json5==0.9.5
# jsonschema==3.2.0
# jupyter-client==6.1.7
# jupyter-core==4.6.3
# jupyterlab==2.2.8
# jupyterlab-pygments==0.1.2
# jupyterlab-server==1.2.0
# lxml==4.6.1
# MarkupSafe==1.1.1
# mistune==0.8.4
# nbclient==0.5.1
# nbconvert==6.0.7
# nbformat==5.0.8
# nest-asyncio==1.4.1
# notebook==6.1.4
# packaging==20.4
# pandocfilters==1.4.2
# parsel==1.6.0
# parso==0.7.1
# pickleshare==0.7.5
# prometheus-client==0.8.0
# prompt-toolkit==3.0.8
# ...
